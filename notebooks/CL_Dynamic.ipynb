# %%
# !pip install avalanche-lib medmnist
# Out:
# Requirement already satisfied: avalanche-lib in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: medmnist in /usr/local/lib/python3.12/dist-packages (3.0.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (4.15.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (5.9.5)
# Requirement already satisfied: gputil in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (1.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (2.0.2)
# Requirement already satisfied: pytorchcv in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (0.0.74)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (0.24.1)
# Requirement already satisfied: tensorboard>=1.15 in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (2.19.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (4.67.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (0.24.0+cu126)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (1.8.2)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (5.2.1)
# Requirement already satisfied: qpsolvers[open_source_solvers] in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (4.8.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (0.3.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from avalanche-lib) (26.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from medmnist) (2.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from medmnist) (0.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from medmnist) (11.3.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from medmnist) (0.7.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (3.10.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=1.15->avalanche-lib) (3.1.5)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->medmnist) (3.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->avalanche-lib) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->avalanche-lib) (3.20.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->avalanche-lib) (2.32.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->avalanche-lib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->medmnist) (2025.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (2026.1.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->avalanche-lib) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->avalanche-lib) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->avalanche-lib) (3.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics->avalanche-lib) (0.15.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (4.5.1)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (6.0.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->avalanche-lib) (2.51.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->avalanche-lib) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->avalanche-lib) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->avalanche-lib) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->avalanche-lib) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->avalanche-lib) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->avalanche-lib) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->avalanche-lib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->avalanche-lib) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->avalanche-lib) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15->avalanche-lib) (3.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->avalanche-lib) (2.8.3)
# Requirement already satisfied: clarabel>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.11.1)
# Requirement already satisfied: cvxopt>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (1.3.2)
# Requirement already satisfied: daqp>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.7.2)
# Requirement already satisfied: ecos>=2.0.8 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (2.0.14)
# Requirement already satisfied: highspy>=1.1.2.dev3 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (1.12.0)
# Requirement already satisfied: jaxopt>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.8.5)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (1.1.0)
# Requirement already satisfied: piqp>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.6.2)
# Requirement already satisfied: proxsuite>=0.2.9 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.7.2)
# Requirement already satisfied: qpalm>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (1.2.6)
# Requirement already satisfied: qpax>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.0.9)
# Requirement already satisfied: quadprog>=0.1.11 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.1.13)
# Requirement already satisfied: scs>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (3.2.11)
# Requirement already satisfied: sip-python>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from qpsolvers[open_source_solvers]->avalanche-lib) (0.0.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->avalanche-lib) (1.7.1)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.4.1->qpsolvers[open_source_solvers]->avalanche-lib) (2.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->avalanche-lib) (5.0.2)
# Requirement already satisfied: jax>=0.2.18 in /usr/local/lib/python3.12/dist-packages (from jaxopt>=0.8.3->qpsolvers[open_source_solvers]->avalanche-lib) (0.7.2)
# Requirement already satisfied: jaxlib>=0.1.69 in /usr/local/lib/python3.12/dist-packages (from jaxopt>=0.8.3->qpsolvers[open_source_solvers]->avalanche-lib) (0.7.2)
# Requirement already satisfied: cmeel in /usr/local/lib/python3.12/dist-packages (from proxsuite>=0.2.9->qpsolvers[open_source_solvers]->avalanche-lib) (0.59.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.2.18->jaxopt>=0.8.3->qpsolvers[open_source_solvers]->avalanche-lib) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.2.18->jaxopt>=0.8.3->qpsolvers[open_source_solvers]->avalanche-lib) (3.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.4.1->qpsolvers[open_source_solvers]->avalanche-lib) (3.0)

# %%
import torch
import torch.nn as nn
from torch import optim
from torchvision import transforms
from medmnist import PathMNIST, INFO
from avalanche.benchmarks import nc_benchmark
from avalanche.models import MultiHeadClassifier, SimpleCNN
from avalanche.training.supervised import Naive, Cumulative
from avalanche.evaluation.metrics import accuracy_metrics, loss_metrics, forgetting_metrics
from avalanche.logging import InteractiveLogger
from avalanche.training.plugins import EvaluationPlugin

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# --- 1. DATA PREPARATION ---
data_flag = 'pathmnist'
info = INFO[data_flag]
n_classes = len(info['label']) # PathMNIST has 9 classes
n_channels = info['n_channels'] # 3 (RGB)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5])
])

# Load MedMNIST datasets
train_dataset = PathMNIST(split='train', transform=transform, download=True)
test_dataset = PathMNIST(split='test', transform=transform, download=True)

import numpy as np

# Load datasets
train_dataset = PathMNIST(split='train', transform=transform, download=True)
test_dataset = PathMNIST(split='test', transform=transform, download=True)

# THE FIX: Flatten and cast to int
# MedMNIST labels are usually shape (N, 1). We need (N,)
train_dataset.labels = train_dataset.labels.flatten().astype(int)
test_dataset.labels = test_dataset.labels.flatten().astype(int)

# Avalanche specific target assignment
train_dataset.targets = train_dataset.labels.tolist()
test_dataset.targets = test_dataset.labels.tolist()

# %%
# --- 2. CREATE THE BENCHMARK ---
# We split the 9 classes into 3 tasks (3 classes each).
# 'return_task_id=True' is mandatory for Multi-head models.
benchmark = nc_benchmark(
    train_dataset, test_dataset,
    n_experiences=3,
    task_labels=True,
    seed=1234,
    shuffle=True
)

# %%
# --- 3. DEFINE THE DYNAMIC MODEL ---
from avalanche.models import MultiTaskModule

class MedMultiHeadCNN(MultiTaskModule): # Inherit from MultiTaskModule
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(n_channels, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten()
        )

        with torch.no_grad():
            dummy_input = torch.randn(1, n_channels, 28, 28)
            self.feature_dim = self.features(dummy_input).shape[1]

        self.classifier = MultiHeadClassifier(in_features=self.feature_dim)

    def forward(self, x, task_labels):
        x = self.features(x)
        # MultiTaskModule expects the output to be routed correctly
        return self.classifier(x, task_labels)

model = MedMultiHeadCNN()

# %%
# --- 4. SET UP THE STRATEGY ---
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Setup Evaluation
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True, stream=True),
    forgetting_metrics(experience=True, stream=True),
    loggers=[InteractiveLogger()]
)

# You can choose between 'Naive' (train only on current task)
# or 'Cumulative' (train on current + all previous data).
strategy = Naive(
    model, optimizer, criterion,
    train_mb_size=128, train_epochs=8, eval_mb_size=128,
    device=device,
    evaluator=eval_plugin
)
# Out:
# /usr/local/lib/python3.12/dist-packages/avalanche/training/templates/base.py:468: PositionalArgumentsDeprecatedWarning: Avalanche is transitioning to strategy constructors that accept named (keyword) arguments only. This is done to ensure that there is no confusion regarding the meaning of each argument (strategies can have many arguments). Your are passing 3 positional arguments to the Naive.__init__ method. Consider passing them as names arguments. The ability to pass positional arguments will be removed in the future.
#   warnings.warn(error_str, category=PositionalArgumentsDeprecatedWarning)

# %%
# --- 5. TRAINING LOOP ---
print("Starting Training Loop...")
for experience in benchmark.train_stream:
    print(f"Current Experience: {experience.current_experience}")
    print(f"Classes in this task: {experience.classes_in_this_experience}")

    # Avalanche handles the model.adaptation() and task_labels internally
    strategy.train(experience)
    print("Training completed. Evaluating on all tasks...")
    strategy.eval(benchmark.test_stream)
# Out:
# Starting Training Loop...
# Current Experience: 0
# Classes in this task: [2, 4, 6]
# -- >> Start of training phase << --
# 100%|██████████| 206/206 [00:13<00:00, 15.31it/s]
# Epoch 0 ended.
# 100%|██████████| 206/206 [00:09<00:00, 22.04it/s]
# Epoch 1 ended.
# 100%|██████████| 206/206 [00:08<00:00, 24.13it/s]
# Epoch 2 ended.
# 100%|██████████| 206/206 [00:07<00:00, 25.85it/s]
# Epoch 3 ended.
# 100%|██████████| 206/206 [00:08<00:00, 23.19it/s]
# Epoch 4 ended.
# 100%|██████████| 206/206 [00:08<00:00, 24.05it/s]
# Epoch 5 ended.
# 100%|██████████| 206/206 [00:11<00:00, 17.52it/s]
# Epoch 6 ended.
# 100%|██████████| 206/206 [00:08<00:00, 24.87it/s]
# Epoch 7 ended.
# -- >> End of training phase << --
# Training completed. Evaluating on all tasks...
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 20.78it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9031
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 21/21 [00:01<00:00, 20.53it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 27.83it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- >> End of eval phase << --
# 	StreamForgetting/eval_phase/test_stream = 0.0000
# 	Top1_Acc_Stream/eval_phase/test_stream/Task002 = 0.2660
# Current Experience: 1
# Classes in this task: [8, 1, 5]
# -- >> Start of training phase << --
# 100%|██████████| 271/271 [00:12<00:00, 22.45it/s]
# Epoch 0 ended.
# 100%|██████████| 271/271 [00:11<00:00, 24.01it/s]
# Epoch 1 ended.
# 100%|██████████| 271/271 [00:10<00:00, 25.78it/s]
# Epoch 2 ended.
# 100%|██████████| 271/271 [00:11<00:00, 23.47it/s]
# Epoch 3 ended.
# 100%|██████████| 271/271 [00:11<00:00, 23.97it/s]
# Epoch 4 ended.
# 100%|██████████| 271/271 [00:10<00:00, 24.90it/s]
# Epoch 5 ended.
# 100%|██████████| 271/271 [00:11<00:00, 24.04it/s]
# Epoch 6 ended.
# 100%|██████████| 271/271 [00:11<00:00, 24.03it/s]
# Epoch 7 ended.
# -- >> End of training phase << --
# Training completed. Evaluating on all tasks...
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 26.96it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.6246
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2785
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 26.07it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9588
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 27.13it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- >> End of eval phase << --
# 	StreamForgetting/eval_phase/test_stream = 0.6246
# 	Top1_Acc_Stream/eval_phase/test_stream/Task002 = 0.4389
# Current Experience: 2
# Classes in this task: [0, 3, 7]
# -- >> Start of training phase << --
# 100%|██████████| 228/228 [00:09<00:00, 22.87it/s]
# Epoch 0 ended.
# 100%|██████████| 228/228 [00:10<00:00, 22.42it/s]
# Epoch 1 ended.
# 100%|██████████| 228/228 [00:09<00:00, 24.21it/s]
# Epoch 2 ended.
# 100%|██████████| 228/228 [00:08<00:00, 26.25it/s]
# Epoch 3 ended.
# 100%|██████████| 228/228 [00:09<00:00, 23.33it/s]
# Epoch 4 ended.
# 100%|██████████| 228/228 [00:09<00:00, 24.18it/s]
# Epoch 5 ended.
# 100%|██████████| 228/228 [00:09<00:00, 23.18it/s]
# Epoch 6 ended.
# 100%|██████████| 228/228 [00:08<00:00, 25.78it/s]
# Epoch 7 ended.
# -- >> End of training phase << --
# Training completed. Evaluating on all tasks...
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 17/17 [00:00<00:00, 21.67it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.4709
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4322
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 21/21 [00:01<00:00, 20.00it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	ExperienceForgetting/eval_phase/test_stream/Task001/Exp001 = 0.4274
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5314
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 27.45it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.9916
# -- >> End of eval phase << --
# 	StreamForgetting/eval_phase/test_stream = 0.4492
# 	Top1_Acc_Stream/eval_phase/test_stream/Task002 = 0.6556

# %%
import json

metrics = strategy.evaluator.get_all_metrics()

with open("dynamic_metrics.json", "w") as f:
    json.dump(metrics, f)
